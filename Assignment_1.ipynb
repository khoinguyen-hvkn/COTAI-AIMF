# %% [markdown]
# <a href="https://colab.research.google.com/github/khoinguyen-hvkn/COTAI-AIMF/blob/master/Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Mount Google Drive
from google.colab import drive # import drive from google colab

ROOT = "/content/drive/"     # default location for the drive
print(ROOT)                 # print content of ROOT (Optional)

drive.mount(ROOT)           # we mount the google drive at /content/drive
# Out:
# /content/drive/
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# #P1.6

# %%
from mpl_toolkits.mplot3d import Axes3D 

import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['legend.fontsize'] = 10

fig = plt.figure()
ax = fig.gca(projection='3d')
def initialize(ax):
  ax.set_xlabel('x')
  ax.set_ylabel('y')
  ax.set_zlabel('z')
  ax.set_xlim([0, 15])
  ax.set_ylim([0, 15])
  ax.set_zlim([0, 15])

initialize(ax)

u = np.array([3,1,3])
v = np.array([2,4,7])
t = 2
w = v+t*u

def vec(v,lb=''):
  ax.plot([0,v[0]], [0,v[1]], [0,v[2]], label=lb)

def seg(u,v,lb=''):
  ax.plot([u[0],v[0]], [u[1],v[1]], [u[2],v[2]], label=lb)
vec(u,'u')
vec(v,'v')
vec(w,'w')
seg(v,w,'w-v')

ax.legend()
plt.show()

# %% [markdown]
# Gọi $W$ là một điểm trên đường thẳng cần tìm, $U,V$ là các điểm thỏa $\overrightarrow{OU}=u,\overrightarrow{OV}=v$ và đặt $\overrightarrow{OW}=w$. Khi đó ta có $\overrightarrow{VW}=w-v$.\
# Mà $VW \parallel OU$ nên $\overrightarrow{VW}=t\overrightarrow{OU}$.
# Suy ra: $w-v=\overrightarrow{VW}=tu \Rightarrow w=v+tu$ \
# Như vậy đường thẳng qua $v$ theo hướng của $u$ là tập hợp tất cả các điểm $W$ thỏa $\overrightarrow{OW}=v+tu$ hay chính là tập $L_1=\{w\in V: w = v+tu, ~\forall t\in\mathbb{R}, ~ u,v\in V\}$

# %% [markdown]
# #P1.9
# Thay $v=0_V$ vào bài trên ta có đường thẳng qua $u$ và $0_V$ chính là tập $L_0=\{w\in V: w = t u, ~ \forall t\in\mathbb{R}, ~ u\in V\}$ \
# Cũng từ hình vẽ trên ta thấy rằng nếu tịnh tiến $L_2$ theo vector $-v$ ta sẽ có được đường thẳng $L'_0$ qua $0_V$ (và qua $u$).

# %% [markdown]
# #P1.7

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')

initialize(ax)
u = np.array([5,3,5])
v = np.array([3,9,11])
t = 0.35
w = (1-t)*v+t*u

vec(u,'u')
vec(v,'v')
vec(w,'w')
seg(u,v)

ax.legend()
plt.show()

# %% [markdown]
# Gọi $W$ là một điểm trên đường thẳng cần tìm, $U,V$ là các điểm thỏa $\overrightarrow{OU}=u,\overrightarrow{OV}=v$ và đặt $\overrightarrow{OW}=w$. \
# Khi đó, ta có: $\overrightarrow{UW}=w-u, \overrightarrow{VW}=w-v$ \
# Do $W$ thuộc đoạn thẳng $UV$ nên $\overrightarrow{UW}=-k \overrightarrow{VW} $
# Suy ra: $w-u=-k(w-v) \Leftrightarrow w=(1-\dfrac{1}{k+1})v+\dfrac{1}{k+1}u$ \
# Đặt $t=\dfrac{1}{k+1}$ thì $w=(1-t)v+tu$ \
# Như vậy đường thẳng qua $U,V$ là tập hợp tất cả các điểm $W$ thỏa $\overrightarrow{OW}=(1-t)v+tu$ hay chính là tập $L_2=\{w\in V: w = (1-t) v + tu, ~ \forall t\in\mathbb{R}, ~ u,v\in V\}$

# %% [markdown]
# #P1.10
# Tương tự $P1.7$ với chú ý rằng với $W$ thuộc đoạn thẳng $U,V$ thì $k \geq 0$ và suy ra $t\in [0,1]$ \
# Như vậy đường thẳng qua $U,V$ là tập hợp tất cả các điểm $W$ thỏa $\overrightarrow{OW}=(1-t)v+tu$ hay chính là tập $L_2=\{w\in V: w = (1-t) v + tu, ~ \forall t\in [0,1], ~ u,v\in V\}$
